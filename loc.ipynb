# %%
import pandas as pd
data = pd.Series([100, 200, 300, 400], index=['x', 'y', 'z', 'w'])

# %%
#1
data.loc['y']
# Out:
# np.int64(200)

# %%
#2
data.iloc[1]
# Out:
# np.int64(200)

# %%
#3
data.loc[['x', 'w']]
# Out:
# x    100
# w    400
# dtype: int64

# %%
#4
data.iloc[-1]
# Out:
# np.int64(400)

# %%
#5
data.loc['y':'z']
# Out:
# y    200
# z    300
# dtype: int64

# %%
#7
data.x
# Out:
# np.int64(100)
