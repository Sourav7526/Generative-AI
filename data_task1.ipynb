# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('neet_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  object
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  object
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  object
#  5   user_description     36510 non-null  object
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  object
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   object
#  11  tweet                47381 non-null  object
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 4.4+ MB

# %%
df.head()
# Out:
#             created_at  retweet_count               source  \
# 0  2020-10-31 14:10:28            141  Twitter for Android
# 1  2020-10-31 14:10:11              1   Twitter for iPhone
# 2  2020-10-31 14:09:48            141      Twitter Web App
# 3  2020-10-31 14:09:41            141  Twitter for Android
# 4  2020-10-31 14:09:22              0  Twitter for Android
#
#                user_id     user_name  \
# 0  1250294694937915394          Rumi
# 1             57059492    Tom Bewick
# 2           1016022678      Lemonade
# 3  1085818329816883201       The Rus
# 4  1227501071490113537  Sakshi Yadav
#
#                                     user_description  user_follower_count  \
# 0                                                NaN                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# 3                                                NaN                  147
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  object
#  1   retweet_count        47381 non-null  int64
#  2   source               47362 non-null  object
#  3   user_id              47381 non-null  int64
#  4   user_name            47380 non-null  object
#  5   user_description     36510 non-null  object
#  6   user_follower_count  47381 non-null  int64
#  7   user_friends_count   47381 non-null  int64
#  8   user_location        26247 non-null  object
#  9   user_verified        47381 non-null  bool
#  10  user_url             9280 non-null   object
#  11  tweet                47381 non-null  object
#  12  length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), object(7)
# memory usage: 4.4+ MB

# %%
df_sort=df.sort_values(by="retweet_count",ascending=False)

# %%
df_sort
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
# ...                    ...            ...                  ...
# 33534  2020-11-07 16:45:39              0      Twitter Web App
# 33533  2020-11-07 16:46:12              0   Twitter for iPhone
# 13611  2020-10-27 01:23:03              0  Twitter for Android
# 33531  2020-11-07 16:48:10              0  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# ...

# %%
highest_retweet=df_sort.iloc[0][['source','retweet_count','user_name','tweet','created_at','user_url']]

# %%
highest_retweet
# Out:
# source                                          Twitter for iPhone
# retweet_count                                               614304
# user_name                     \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# tweet            RT @JoeBiden: America, I\xe2\x80\x99m honored ...
# created_at                                     2020-11-08 05:30:01
# user_url                                   https://t.co/cHZdP4uOdu
# Name: 32860, dtype: object

# %%
top10 = df_sort.head(10)

# %%
top10_sum = top10['retweet_count'].sum()

# %%
top10_sum
# Out:
# np.int64(2652225)

# %% [markdown]
# **TOP 10 Retweet sum is 2652225**

# %%
android_tweets = df[df['source'] == 'Twitter for Android']

# %%
android_tweets.shape[0]
# Out:
# 28850

# %%
max_index = df_sort['user_follower_count'].idxmax()
df_sort.loc[max_index, ['user_name', 'user_location']]
# Out:
# user_name         NDTV
# user_location    India
# Name: 44367, dtype: object

# %%
android_tweets['retweet_count'].sum()
# Out:
# np.int64(9386742)

# %%
ratio = (df['user_follower_count'] / df['user_friends_count'])

# %%
df.insert(2, 'followers_friend_ratio', ratio)

# %%
df.isnull().sum()
# Out:
# created_at                    0
# retweet_count                 0
# followers_friend_ratio      147
# source                       19
# user_id                       0
# user_name                     1
# user_description          10871
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# dtype: int64

# %%
df['user_description'].fillna('Twitter user')
# Out:
# 0                                             Twitter user
# 1        Proud dad of three & cat, @SussexCCC fan. CEO ...
# 2        Wisdom is knowing the right path to take, Inte...
# 3                                             Twitter user
# 4                       it's not my attitude it's my style
#                                ...
# 47376                                       Bhola sa chora
# 47377    Random person who likes drawing (but not a \nl...
# 47378                                         Twitter user
# 47379    Finding the enemies of India \xf0\x9f\x87\xae\...
# 47380    404: \xd8\xaf\xd9\x8a\xd8\xa7\xd9\x86\xd8\xa9 ...
# Name: user_description, Length: 47381, dtype: object

# %%
df.dropna(axis=1, inplace=True)

# %%
df.insert(2, 'is_allow', True)

# %%
df.drop('tweet',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  object
#  1   retweet_count        47381 non-null  int64
#  2   is_allow             47381 non-null  bool
#  3   user_id              47381 non-null  int64
#  4   user_follower_count  47381 non-null  int64
#  5   user_friends_count   47381 non-null  int64
#  6   user_verified        47381 non-null  bool
#  7   length_of_tweet      47381 non-null  int64
# dtypes: bool(2), int64(5), object(1)
# memory usage: 2.3+ MB
